# %% [markdown]
# # Exploratory Data Analysis Starter
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas
#
# We need to load `client_data.csv` and `price_data.csv` into individual dataframes so that we can work with them in Python. For this notebook and all further notebooks, it will be assumed that the CSV files will the placed in the same file location as the notebook. If they are not, please adjust the directory within the `read_csv` method accordingly.

# %%
client_df = pd.read_csv('C:/Users/User/Desktop/BCGX/client_data.csv')
price_df = pd.read_csv('C:/Users/User/Desktop/BCGX/price_data.csv')

# %% [markdown]
# You can view the first 3 rows of a dataframe using the `head` method. Similarly, if you wanted to see the last 3, you can use `tail(3)`

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
client_df.tail(3)
# Out:
#                                      id                     channel_sales  \
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 14603      1844             0              179  2012-02-08  2016-02-07
# 14604       131             0                0  2012-08-30  2016-08-30
# 14605      8730             0                0  2009-12-18  2016-12-17
#
#       date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 14603      2012-02-08   2015-02-09             190.39  ...        f     18.05
# 14604      2012-08-30   2015-08-31              19.34  ...        f      0.00
# 14605      2009-12-18   2015-12-21             762.41  ...        f      0.00
#
# ...

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %%
price_df.tail(3)
# Out:
#                                       id  price_date  price_off_peak_var  \
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01            0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01            0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01            0.119916
#
#         price_peak_var  price_mid_peak_var  price_off_peak_fix  \
# 192999        0.102232            0.076257           40.728885
# 193000        0.102232            0.076257           40.728885
# 193001        0.102232            0.076257           40.728885
#
#         price_peak_fix  price_mid_peak_fix
# 192999        24.43733           16.291555
# 193000        24.43733           16.291555
# 193001        24.43733           16.291555

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.
#
# To get an overview of the data types within a data frame, use the `info()` method.

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Statistics
#
# Now let's look at some statistics about the datasets. We can do this by using the `describe()` method.

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# ---
#
# ## Data visualization
#
# If you're working in Python, two of the most popular packages for visualization are `matplotlib` and `seaborn`. We highly recommend you use these, or at least be familiar with them because they are ubiquitous!
#
# Below are some functions that you can use to get started with visualizations.

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# Thhe first function `plot_stacked_bars` is used to plot a stacked bar chart. An example of how you could use this is shown below:

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %% [markdown]
# Thank you Estelle, The .info() function effectively displays the data types present in the dataset provided, but I would like to output this information using an alternative method.

# %%
Column_client_df = print(client_df.dtypes)
#Column_client_df = print(client_df.info())
# Out:
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# forecast_price_pow_off_peak       float64
# has_gas                            object
# imp_cons                          float64
# margin_gross_pow_ele              float64
# margin_net_pow_ele                float64
# nb_prod_act                         int64
# net_margin                        float64
# ...

# %%
Column_price_df = print(price_df.dtypes)
#Column_price_df = print(price_df.info())
# Out:
# id                     object
# price_date             object
# price_off_peak_var    float64
# price_peak_var        float64
# price_mid_peak_var    float64
# price_off_peak_fix    float64
# price_peak_fix        float64
# price_mid_peak_fix    float64
# dtype: object

# %% [markdown]
# "The distinction between the `.info()` function and the `.dtypes` attribute lies in their outputs:
#
# - `.info()` provides a comprehensive overview of the dataset, detailing total cell count, indexing information (e.g., from 0 to 25 for the first client dataframe), and similar details for each dataset.
# - In contrast, `.dtypes` solely presents a succinct listing of each cell's data type within the dataset."

# %% [markdown]
# "I will conduct a focused descriptive statistical analysis on the 'churn' attribute to better understand its characteristics within our dataset. This analysis will include calculating the mean and standard deviation using the `describe()` method, aligning with the approach used by our senior Data Analst."

# %%
churn_attribute = client_df['churn']
churn_attribute.describe()
# Out:
# count    14606.000000
# mean         0.097152
# std          0.296175
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: churn, dtype: float64

# %% [markdown]
# I have the option to compute the mean and standard deviation, two crucial measures of central tendency for this analysis, using alternative methodologies. This approach allows for flexibility in deriving precise statistical insights pertinent to the 'churn' attribute within the dataset, essential for informing strategic decisions regarding customer retention at PowerCo.

# %%
churn_mean = churn_attribute.mean()
churn_std = churn_attribute.std()

print(f"Mean churn rate: {churn_mean}")
print(f"Standard deviation of churn rate: {churn_std}")
# Out:
# Mean churn rate: 0.09715185540188963
# Standard deviation of churn rate: 0.2961745736932014

# %% [markdown]
# This indicates that the churn rate could fluctuate around the mean by ±0.296. Given that churn rates cannot be negative, the possible range extends from the mean of 0.097 up to a maximum of 0.393. This substantial variability suggests that churn rates can differ significantly from one period to another, depending on the time frame analyzed (e.g., monthly or otherwise). Consequently, there may be periods with a churn rate as low as 0%, and others where it could rise notably to 39.3%, reflecting considerable variability. To further understand this variability, we will visualize the churn attribute.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example client_df setup (replace with your actual data)
#client_df = pd.DataFrame({
 #   'id': [1, 2, 3, 4, 5],
  #  'churn': [0, 1, 0, 0, 1]  # Example churn status (0: retained, 1: churned)
#})

# Extract churn data
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'Churn']

# Calculate churn percentages
churn_total = churn.groupby('Churn').count()
churn_percentage = churn_total / churn_total.sum() * 100

# Plotting a pie chart
plt.figure(figsize=(6, 6))
labels = churn_percentage.index.map({0: 'Retention', 1: 'Churn'})
sizes = churn_percentage['Companies']
colors = ['lightblue', 'salmon']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Churn Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# From our visualization, we observe that the churn rate is 9.7%. This figure aligns with our descriptive statistical analysis, which calculated the mean churn rate as 0.097 (or 9.7%). The consistency between the observed churn rate and the mean derived from our statistical analysis indicates that our descriptive statistics accurately reflect the central tendency of the churn data.
#
# To further validate, the standard deviation calculated (0.296) indicates variability around this mean, suggesting that while the average churn rate is 9.7%, actual churn rates could vary significantly, potentially ranging from near zero to 39.3%. This variability is expected and consistent with the broad range observed in our descriptive statistics.

# %%
plt.figure(figsize=(12, 6))

# Example: Price Off-Peak Variance vs Churn
sns.scatterplot(data=client_df, x='forecast_price_energy_off_peak', y='churn')
plt.title('Price Off-Peak Variance vs Churn')
plt.xlabel('Forecast Price Energy Off-Peak')
plt.ylabel('Churn')
plt.grid(True)
plt.show()

# Example: Price Peak Variance vs Churn
plt.figure(figsize=(12, 6))
sns.scatterplot(data=client_df, x='forecast_price_energy_peak', y='churn')
plt.title('Price Peak Variance vs Churn')
plt.xlabel('Forecast Price Energy Peak')
plt.ylabel('Churn')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Example: 12-Month Consumption vs Churn
sns.scatterplot(data=client_df, x='cons_12m', y='churn')
plt.title('12-Month Consumption vs Churn')
plt.xlabel('12-Month Consumption')
plt.ylabel('Churn')
plt.grid(True)
plt.show()

# Example: Forecast Consumption vs Churn
plt.figure(figsize=(12, 6))
sns.scatterplot(data=client_df, x='forecast_cons_12m', y='churn')
plt.title('Forecast Consumption vs Churn')
plt.xlabel('Forecast Consumption 12M')
plt.ylabel('Churn')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Box plot of price off-peak variance by churn status
sns.boxplot(data=client_df, x='churn', y='forecast_price_energy_off_peak')
plt.title('Price Off-Peak Variance by Churn Status')
plt.xlabel('Churn')
plt.ylabel('Forecast Price Energy Off-Peak')
plt.grid(True)
plt.show()

# Box plot of 12-month consumption by churn status
plt.figure(figsize=(12, 6))
sns.boxplot(data=client_df, x='churn', y='cons_12m')
plt.title('12-Month Consumption by Churn Status')
plt.xlabel('Churn')
plt.ylabel('12-Month Consumption')
plt.grid(True)
plt.show()

# %%
import statsmodels.api as sm

# Example of regression model: Churn as a function of price sensitivity and demand elasticity
X = client_df[['forecast_price_energy_off_peak', 'forecast_price_energy_peak', 'cons_12m', 'forecast_cons_12m']]
X = sm.add_constant(X)  # Adds a constant term to the predictor
y = client_df['churn']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  churn   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     13.35
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           7.33e-11
# Time:                        13:07:19   Log-Likelihood:                -2925.2
# No. Observations:               14606   AIC:                             5860.
# Df Residuals:                   14601   BIC:                             5898.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...
